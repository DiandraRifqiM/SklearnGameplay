# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# Sample Data

# %%
pizza = {
    "Slice":[5, 7, 12, 16, 20],
    "Price":[3.55, 5.23, 7.35, 13.43, 16.44]
}

pizzaDf = pd.DataFrame(pizza)

# %% [markdown]
# Transform

# %%
X = np.array(pizzaDf["Slice"])
y = np.array(pizzaDf["Price"])

# Reshape

X = X.reshape(-1, 1)

# %% [markdown]
# Simple Linear Regression Model

# %%
from sklearn.linear_model import LinearRegression
linRegModel = LinearRegression()
linRegModel.fit(X, y)
# Out:
# LinearRegression()

# %% [markdown]
# Data Visualization

# %%
x_vis = np.array([0, 25]).reshape(-1, 1)
y_vis = linRegModel.predict(x_vis)

plt.style.use("ggplot")
plt.scatter(X, y, color="cyan", edgecolors="blue", linewidths=0.5)
plt.plot(x_vis, y_vis, '-r')
plt.title("Pizza Slice vs Price Comparison")
plt.xlabel("Pizza Slices")
plt.ylabel("Prices (USD)")
plt.xlim(0, 25)
plt.ylim(0, 25)
# Out:
# (0.0, 25.0)

# %% [markdown]
# Pizza Price Predict

# %%
newSlice = np.array([14, 6, 18, 25]).reshape(-1, 1)
predPrice = linRegModel.predict(newSlice)
fixedPrice = np.round(predPrice, decimals=2)

# %%
for slices, price in zip(newSlice, fixedPrice):
    print(f"Pizza Slices:{slices} : ${price}")
# Out:
# Pizza Slices:[14] : $10.94
# Pizza Slices:[6] : $3.97
# Pizza Slices:[18] : $14.43
# Pizza Slices:[25] : $20.53

# %% [markdown]
# Train Test Model

# %%
X_train = np.array([12, 16, 20, 28, 32]).reshape(-1, 1)
y_train = np.array([14, 18, 26, 35.5, 32])

X_test = np.array([16, 18, 22, 32, 24]).reshape(-1, 1)
y_test = np.array([22, 16.5, 30, 36, 22])

# %%
trainModel = LinearRegression()
trainModel.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# Evaluate Model

# %%
from sklearn.metrics import r2_score

yPred = linRegModel.predict(X_test)
accuracy = r2_score(y_test, yPred)
accuracy
# Out:
# -0.4004383396914373
